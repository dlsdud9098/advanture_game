# %%
import pickle
from entity.armor import Armor
import pandas as pd

# %%
from entity.armor import Armor

armor = Armor()
datas1 = {
    "name": "하급 회복 물약",
    "description": "체력을 약간 회복시켜준다.",
    "required_stat": {},
    "required_class": [],
    "up_stat": {},
    "attack": 0,
    "defense": 0,
    "hp": 100,
    "mp": 0,
    "drop": 0,
    "type": "소모품",
}

datas2 = {
    "name": "철 검",
    "description": "강철로 만든 철 검이다.",
    "required_stat": {"STR": 10},
    "required_class": ["Warrior"],
    "up_stat": {"STR": 10},
    "attack": 50,
    "defense": 0,
    "hp": 0,
    "mp": 0,
    "drop": 0,
    "type": "한 손 무기",
}

datas3 = {
    "name": "철 갑옷",
    "description": "강철로 만든 철 갑옷이다.",
    "required_stat": {"STR": 15},
    "required_class": ["Warrior"],
    "up_stat": {"STR": 10},
    "attack": 0,
    "defense": 50,
    "hp": 0,
    "mp": 0,
    "drop": 0,
    "type": "갑옷",
}

datas4 = {
    "name": "가죽",
    "description": "가죽이다.",
    "required_stat": {},
    "required_class": [],
    "up_stat": {},
    "attack": 0,
    "defense": 0,
    "hp": 0,
    "mp": 0,
    "drop": 0,
    "type": "재료",
}

datas5 = {
    "name": "철 반지",
    "description": "철로 만든 반지다.",
    "required_stat": {"STR": 5, "INT": 5},
    "required_class": [],
    "up_stat": {"STR": 5, "INT": 5},
    "attack": 50,
    "defense": 50,
    "hp": 50,
    "mp": 50,
    "drop": 0,
    "type": "반지",
}
# datas = {}
# armor.AddItem(datas1)
armor.AddItem(datas2)
# armor.AddItem(datas3)
# armor.AddItem(datas4)
# armor.AddItem(datas5)
# print(armor.LoadData())
# Out:
#        name     description         required_stat required_class  \
# 0  하급 회복 물약  체력을 약간 회복시켜준다.                    {}             []
# 1      철 갑옷  강철로 만든 철 갑옷이다.           {'STR': 15}      [Warrior]
# 2        가죽           가죽이다.                    {}             []
# 3      철 반지      철로 만든 반지다.  {'STR': 5, 'INT': 5}             []
#
#                 up_stat  attack  defense   hp  mp  drop type
# 0                    {}       0        0  100   0     0  소모품
# 1           {'STR': 10}       0       50    0   0     0   갑옷
# 2                    {}       0        0    0   0     0   재료
# 3  {'STR': 5, 'INT': 5}      50       50   50  50     0   반지

# %%
import pickle
from entity.armor import Armor

armor = Armor()
armor.DeleteItem("철 검")
# Out:
#        name     description         required_stat required_class  \
# 0  하급 회복 물약  체력을 약간 회복시켜준다.                    {}             []
# 1       철 검   강철로 만든 철 검이다.           {'STR': 10}      [Warrior]
# 2      철 갑옷  강철로 만든 철 갑옷이다.           {'STR': 15}      [Warrior]
# 3        가죽           가죽이다.                    {}             []
# 4      철 반지      철로 만든 반지다.  {'STR': 5, 'INT': 5}             []
#
#                 up_stat  attack  defense   hp  mp  drop type
# 0                    {}       0        0  100   0     0  소모품
# 1           {'STR': 10}      50        0    0   0     0   무기
# 2           {'STR': 10}       0       50    0   0     0   갑옷
# 3                    {}       0        0    0   0     0   재료
# 4  {'STR': 5, 'INT': 5}      50       50   50  50     0   반지

# %%
import pickle
from entity.armor import Armor
import pandas as pd


armor = Armor()
print(armor.LoadArmor())
# Out:
# Empty DataFrame
# Columns: [name, item_name, item_description, attack, defense, hp, mp, stat, drop, type]
# Index: []
# None

# %%
import pickle
from entity.item import Item


item_svld = Item()
item_svld.AllItemLoad()
# Out:
# Empty DataFrame
# Columns: [name, description, required_stat, required_class, up_stat, attack, defense, hp, mp, drop, type, item_name, item_description, stat]
# Index: []

# %%
import pickle

with open("./data/data_files/item_datas.item", "rb") as f:
    a = pickle.load(f)
a
# Out:
#        name     description required_stat required_class up_stat  attack  \
# 0  하급 회복 물약  체력을 약간 회복시켜준다.            {}             []      {}       0
#
#    defense   hp  mp  drop type
# 0        0  100   0     0  소모품

# %%
import pickle
from data.item_data import Item_SAVELOAD

item_svld = Item_SAVELOAD()
item_svld.LoadData()
# Out:
#        name     description         required_stat required_class  \
# 0  하급 회복 물약  체력을 약간 회복시켜준다.                    {}             []
# 1      철 갑옷  강철로 만든 철 갑옷이다.           {'STR': 15}      [Warrior]
# 2        가죽           가죽이다.                    {}             []
# 3      철 반지      철로 만든 반지다.  {'STR': 5, 'INT': 5}             []
# 4       철 검   강철로 만든 철 검이다.           {'STR': 10}      [Warrior]
#
#                 up_stat  attack  defense   hp  mp  drop    type
# 0                    {}       0        0  100   0     0     소모품
# 1           {'STR': 10}       0       50    0   0     0      갑옷
# 2                    {}       0        0    0   0     0      재료
# 3  {'STR': 5, 'INT': 5}      50       50   50  50     0      반지
# 4           {'STR': 10}      50        0    0   0     0  한 손 무기
#        name     description         required_stat required_class  \
# 0  하급 회복 물약  체력을 약간 회복시켜준다.                    {}             []
# ...
